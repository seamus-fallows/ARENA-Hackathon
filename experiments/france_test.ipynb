# %%
import sys
sys.path.append("..")
from lib import Llama_Leaner, generate_data, CachedDataset
from transformers import AutoTokenizer, AutoModelForCausalLM

import torch as t
llama_token = "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"
device = t.device("cuda" if t.cuda.is_available() else "cpu")

# %%
tokenizer = AutoTokenizer.from_pretrained(
            "meta-llama/Llama-2-7b-chat-hf", ignore_mismatched_sizes=True, use_auth_token=llama_token
        )
model = AutoModelForCausalLM.from_pretrained(
            f"meta-llama/Llama-2-7b-chat-hf", use_auth_token=llama_token
        ).to(device)
# Out:
# /root/miniconda/envs/my_env/lib/python3.9/site-packages/transformers/models/auto/tokenization_auto.py:711: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /root/miniconda/envs/my_env/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py:472: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
numb_strings_1 = [str(i) for i in range(10)]
numb_strings_2 = ["one", "two", "three", "four", "five", "six", "seven", "eight", "nine", "ten"]
numb_tokens_1 = tokenizer.batch_encode_plus(numb_strings_1, return_tensors='pt')['input_ids'][:,-1].flatten()
numb_tokens_2 = tokenizer.batch_encode_plus(numb_strings_2, return_tensors='pt')['input_ids'][:,-1].flatten()
number_tokens = t.cat([numb_tokens_1, numb_tokens_2])
# other_tokens = tokenizer.batch_encode_plus([chr(i) for i in range(97, 123)], return_tensors='pt')['input_ids'][:,-1].flatten()
data_token_ids, labels = generate_data.generate_data_tokens(n_data = 10, seq_len = 10, concept_tokens = number_tokens, vocab_size=tokenizer.vocab_size, p_concept=.3)
print(labels)
for i in range(data_token_ids.size(0)):
    sequence = data_token_ids[i].tolist()
    decoded_sequence = tokenizer.decode(sequence)
    print(decoded_sequence)
prompt = dict(
    system_prompt="You are a question answering assistent, you always follow instructions exactly and always answer questions correctly. Answer every question with either 'Yes' or 'No'.",
    user_prompt=lambda sentence, concept, token: f"'{sentence}'Is the word '{token}' an example of a {concept}? Answer 'Yes' if it IS a magic. Answer 'No' if it is NOT a magic. Think carefully about your answer and be confident in your response.",
    ai_answer="Answer: ",
)

data_token_ids = [list(i) for i in data_token_ids]
dataset = CachedDataset.CachedDataset(model, tokenizer, data_token_ids, labels,prompt )
# Out:
# tensor([[False, False, False, False, False, False,  True,  True,  True, False],
#         [ True,  True, False, False, False, False, False,  True,  True,  True],
#         [False,  True, False, False, False,  True,  True, False, False, False],
#         [ True, False, False,  True, False, False,  True, False,  True,  True],
#         [False,  True, False, False, False, False,  True, False, False, False],
#         [False, False, False,  True,  True, False, False, False, False,  True],
#         [False,  True, False, False,  True, False, False, False,  True,  True],
#         [False, False,  True, False, False, False, False,  True, False, False],
#         [ True, False,  True, False, False, False, False, False, False,  True],
#         [False,  True,  True,  True,  True, False, False, False, False,  True]])
# gew Het ou coordinateוἄ two four five~~~~
# seven sevensetState当 displaypty admin0 eight0
# enza nine Krak Charles Пари five4 Rome名="<?
# 3 authentication kindly5мостиives2 Institute80
# dataset0 proof culturalbeeld partic6 populated trat включа
# Angle og Herr nine one términURL Antoietnam five
# ership four detail Content1 discussedpython科7 eight
# excitementния1Add :-)ню Well8ব Ign
# five positions six як Lane:/ Stationenson criter eight
# Career956 twomovie nimprotocol призна3

# %%
config = Llama_Leaner.Config()
config.magic_word = "magic"
config.loss_coeffs = {"label": 1.0, "kl": 0.5, "entropy": .5}
config.lr =.1
config.batch_size = 30
config.epochs = 3
dataloader = CachedDataset.CachedDataloader(dataset, batch_size=config.batch_size, shuffle=True, device =device)


training = Llama_Leaner.Training(config, model, tokenizer)
solution = [tokenizer.encode("Numbers")[-1],tokenizer.encode("numbers")[-1]]

trainings_logs = training.train(
    dataloader, specified_tokens=solution, n_top_tracked_tokens=5
)
trainings_logs.plot_losses(tokenizer)
trainings_logs.plot_top_tokens(tokenizer)
trainings_logs.plot_loss_tradeoff(tokenizer)
#%%
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# /root/ARENA-Hackathon/experiments/../lib/Llama_Leaner.py:379: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   magic_porobs = t.nn.functional.softmax(self.magic_token_vector)
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[4], line 13
#      10 training = Llama_Leaner.Training(config, model, tokenizer)
#      11 solution = [tokenizer.encode("Numbers")[-1],tokenizer.encode("numbers")[-1]]
# ---> 13 trainings_logs = training.train(
#      14     dataloader, specified_tokens=solution, n_top_tracked_tokens=5
#      15 )
#      16 trainings_logs.plot_losses(tokenizer)
#      17 trainings_logs.plot_top_tokens(tokenizer)
#
# File ~/ARENA-Hackathon/experiments/../lib/Llama_Leaner.py:489, in Training.train(self, dataloader, specified_tokens, wandb_log, n_top_tracked_tokens)
#     486 for id in self.top_token_log.keys():
#     487     self.top_token_log[id]["max_prob"] = max(self.top_token_log[id]["prob"])
# --> 489 self.add_ratings_to_id_log(dataloader, n_top_tracked_tokens)
#     491 logs = Logs(
#     492     self.loss_log,
#     493     self.top_token_log,
#    (...)
#     499     time,
#     500 )
#     501 return logs
#
# File ~/ARENA-Hackathon/experiments/../lib/Llama_Leaner.py:419, in Training.add_ratings_to_id_log(self, dataloader, n_top_tracked_tokens)
#     415 magic_token_pos = question_end_tokens == self.magic_ids
#     416 embeddings = self.create_modified_embeddings(
#     417     question_end_tokens, magic_token_pos, onehot_vector
#     418 )
# --> 419 output_logits = self.model(
#     420     inputs_embeds=embeddings,
#     421     past_key_values=caches,
#     422     attention_mask=attention_masks,
#     423 ).logits
#     424 (
#     425     total_loss,
#     426     label_loss,
#    (...)
#     430     output_logits, onehot_vector, magic_token_pos, target_tokens
#     431 )
#     432 log[id]["total_loss"] = total_loss.item()
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/transformers/models/llama/modeling_llama.py:1183, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1180 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1182 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1183 outputs = self.model(
#    1184     input_ids=input_ids,
#    1185     attention_mask=attention_mask,
#    1186     position_ids=position_ids,
#    1187     past_key_values=past_key_values,
#    1188     inputs_embeds=inputs_embeds,
#    1189     use_cache=use_cache,
#    1190     output_attentions=output_attentions,
#    1191     output_hidden_states=output_hidden_states,
#    1192     return_dict=return_dict,
#    1193 )
#    1195 hidden_states = outputs[0]
#    1196 if self.config.pretraining_tp > 1:
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/transformers/models/llama/modeling_llama.py:1070, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1060     layer_outputs = self._gradient_checkpointing_func(
#    1061         decoder_layer.__call__,
#    1062         hidden_states,
#    (...)
#    1067         use_cache,
#    1068     )
#    1069 else:
# -> 1070     layer_outputs = decoder_layer(
#    1071         hidden_states,
#    1072         attention_mask=attention_mask,
#    1073         position_ids=position_ids,
#    1074         past_key_value=past_key_values,
#    1075         output_attentions=output_attentions,
#    1076         use_cache=use_cache,
#    1077     )
#    1079 hidden_states = layer_outputs[0]
#    1081 if use_cache:
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/transformers/models/llama/modeling_llama.py:798, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     795 hidden_states = self.input_layernorm(hidden_states)
#     797 # Self Attention
# --> 798 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     799     hidden_states=hidden_states,
#     800     attention_mask=attention_mask,
#     801     position_ids=position_ids,
#     802     past_key_value=past_key_value,
#     803     output_attentions=output_attentions,
#     804     use_cache=use_cache,
#     805     **kwargs,
#     806 )
#     807 hidden_states = residual + hidden_states
#     809 # Fully Connected
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/transformers/models/llama/modeling_llama.py:706, in LlamaSdpaAttention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     703     kv_seq_len += past_key_value.get_usable_length(kv_seq_len, self.layer_idx)
#     704 cos, sin = self.rotary_emb(value_states, seq_len=kv_seq_len)
# --> 706 query_states, key_states = apply_rotary_pos_emb(query_states, key_states, cos, sin, position_ids)
#     708 if past_key_value is not None:
#     709     cache_kwargs = {"sin": sin, "cos": cos}  # Specific to RoPE models
#
# File ~/miniconda/envs/my_env/lib/python3.9/site-packages/transformers/models/llama/modeling_llama.py:234, in apply_rotary_pos_emb(q, k, cos, sin, position_ids, unsqueeze_dim)
#     232 cos = cos[position_ids].unsqueeze(unsqueeze_dim)
#     233 sin = sin[position_ids].unsqueeze(unsqueeze_dim)
# --> 234 q_embed = (q * cos) + (rotate_half(q) * sin)
#     235 k_embed = (k * cos) + (rotate_half(k) * sin)
#     236 return q_embed, k_embed
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 26.00 MiB. GPU 0 has a total capacity of 79.15 GiB of which 21.75 MiB is free. Process 2630371 has 79.10 GiB memory in use. Of the allocated memory 77.64 GiB is allocated by PyTorch, and 995.23 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
len(dataloader)
# Out:
# 4

# %%
tokenizer.encode(" Token:")
# Out:
# [1, 29871, 25159, 29901]

# %%
import numpy as np
import torch.nn.functional as F
from tqdm import tqdm
probs_on_label = np.array([])
random_embedding = t.rand((2,5,model.config.hidden_size)).to(device)
for sentence_cache, question_end_ids, label in tqdm(dataloader):
    output = model(
        question_end_ids, past_key_values=sentence_cache, return_dict=True
    )
    output_probs = F.softmax(output.logits, dim=-1)
    prob_on_label = output_probs[0, -1, label].detach().cpu().numpy()
    probs_on_label = np.append(probs_on_label, prob_on_label)


    print(question_end_ids.shape)
    print(sentence_cache[0][0].shape)
    print(len(sentence_cache[0]))
    print(len(sentence_cache))
    break

#print(probs_on_label)
#print(np.mean(probs_on_label))
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# torch.Size([2, 13])
# torch.Size([2, 32, 121, 128])
# 2
# 32

# %%
random_embedding = t.rand((2,5,model.config.hidden_size)).to(device)

output = model(inputs_embeds = random_embedding, past_key_values=sentence_cache,return_dict=True)
output.logits.shape
# Out:
# torch.Size([2, 5, 32000])

# %%
type(sentence_cache)
# Out:
# tuple

# %%
random_embedding = t.rand((2,5,model.config.hidden_size)).to(device)

# %%
output = model(inputs_embeds = random_embedding, return_dict=True, past_key_values = sentence_cache)

# %%
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [[tensor([[[[[-4.2001e-01,  5.3387e-03,  6.2983e-02,  ...,  1.0673e-01,
#             -7.3656e-02, -5.5029e-02],
#            [-4.9449e-01, -1.2441e-02, -8.1780e-02,  ...,  6.6577e-01,
#             -7.4171e-01,  6.3368e-01],
#            [-3.0075e-01,  8.1640e-03, -1.3310e-01,  ...,  2.2132e-01,
#             -3.4279e-02,  2.5279e-01],
#            ...,
#            [-4.6499e-02, -1.9034e-02,  3.1313e-01,  ...,  2.0804e-01,
#            [ 6.6671e-03,  1.7113e-03,  3.1661e-03,  ..., -4.1605e-03,
#              7.5204e-03,  4.5935e-03],
#            [ 4.2360e-03,  1.2106e-02, -2.6164e-03,  ...,  5.7408e-03,
#             -9.3310e-03,  1.2760e-02],
#            [ 2.3060e-03,  2.4522e-03,  7.4467e-03,  ..., -3.1517e-03,
#             -8.1594e-03, -1.2091e-03]],
#
#           [[-3.0863e-03, -4.9198e-03,  3.7030e-03,  ...,  2.3944e-03,
#              6.9353e-03,  1.1707e-02],
#            [ 1.1020e-03,  5.4037e-03,  5.8339e-03,  ..., -8.7046e-03,
#              1.8884e-03,  3.6302e-03],
#            [-3.6341e-04, -7.5152e-03, -1.1090e-02,  ...,  4.1862e-03,
#             -3.1095e-03, -8.0183e-03],
#            ...,
#            [-1.9366e-03, -7.9004e-03,  3.0345e-03,  ..., -2.3761e-02,
#              9.0933e-03,  3.2234e-03],
#            [ 5.1489e-03, -1.9400e-02,  2.1811e-03,  ..., -5.2659e-04,
#             -6.0698e-03, -4.2699e-03],
#            [-4.7478e-03, -3.5022e-03, -2.4576e-03,  ..., -7.9267e-03,
#             -4.7262e-03, -1.9287e-03]]]]], device='cuda:0')], [tensor([[[[[ 0.0552,  0.5317,  0.5295,  ..., -0.0731, -0.2252,  0.0196],
#            [-2.0945,  0.0116, -0.8654,  ..., -0.8724, -0.9924,  0.3873],
#            [-0.9469,  0.3648, -1.1638,  ..., -0.8540, -1.3454,  0.9339],
#            ...,
#            [-0.4847, -0.0186,  0.5520,  ..., -1.2883, -1.7532,  1.2392],
#            [-0.1756, -0.2729,  0.0439,  ..., -1.2843, -1.5183,  1.4094],
#            [-0.0476, -0.2487, -1.0425,  ..., -1.0720, -1.3568,  0.4571]],
#
#           [[-0.0601, -0.3936,  0.0745,  ...,  0.4253,  0.4963,  0.5316],
#            [-0.1687,  0.3556, -0.3881,  ..., -0.6594, -0.4454, -0.1677],
#            [ 0.5371,  0.7499, -0.6113,  ..., -0.8731, -1.1460, -0.6331],
#            ...,
#            [ 0.4943,  0.6719, -0.5366,  ..., -1.2143, -1.0001, -0.7241],
#            [ 1.1591,  0.4003, -0.2913,  ..., -0.8941, -0.3052, -0.6770],
#            [-0.0082, -0.0264, -0.2877,  ..., -0.8639, -0.3953, -0.1595]],
#
#           [[-0.0408,  0.3479,  0.5089,  ...,  1.2307,  0.8891,  0.2085],
#            [ 0.1789, -0.3935, -0.0379,  ...,  1.2651,  0.6142,  0.5932],
#            [ 0.1796, -0.4455, -0.0925,  ...,  1.0010,  0.5736,  0.5438],
#            ...,
#            [ 0.5738, -0.0223, -0.3572,  ...,  1.2727,  0.8595,  0.5305],
#            [ 0.1048,  0.1128, -0.1263,  ...,  1.1927,  0.6619,  0.7334],
#            [-0.0526,  0.3178,  0.1345,  ...,  1.4390,  0.7568,  0.7192]],
#
#           ...,
#
#           [[-0.7178,  0.0251,  0.0275,  ...,  0.8255, -0.1660, -0.1873],
#            [-0.5204, -0.2522, -0.0775,  ...,  0.1294, -0.1471,  0.1392],
#            [-0.1134, -0.1637, -0.0870,  ...,  0.0523, -0.1457,  0.1636],
#            ...,
#            [-0.1792, -0.0911,  0.0708,  ..., -0.1463, -0.0092, -0.0590],
#            [-0.6705, -0.4106,  0.0813,  ..., -0.4875,  0.2410, -0.1970],
#            [ 0.3894, -0.1582,  0.0604,  ..., -0.3028, -0.0351,  0.6630]],
#
#           [[ 0.2312,  0.2540, -0.0892,  ..., -0.3061,  0.4718,  0.3059],
#            [ 0.0311, -0.1132,  0.0414,  ..., -0.4607, -0.0194, -0.7185],
#            [-0.6061, -0.3382, -0.5118,  ...,  0.1854, -0.4115,  0.4283],
#            ...,
#            [ 0.2495,  0.3023,  0.4910,  ...,  0.1408, -0.6909,  0.5082],
#            [-0.5602,  0.4960, -0.6482,  ...,  0.5801, -0.9895,  0.2136],
#            [-0.2779,  0.0966,  0.0483,  ...,  0.1526, -0.3013, -0.7780]],
#
#           [[-0.0152, -0.0364,  0.0847,  ...,  0.4414, -0.4385,  0.2955],
#            [-0.1072, -0.0936,  0.2509,  ...,  1.0719, -1.1046,  0.7198],
#            [ 0.1070,  0.2247,  0.1788,  ...,  1.3554, -1.3737,  0.9566],
#            ...,
#            [-0.2578,  0.1288,  0.4826,  ...,  1.6375, -1.7042,  1.1599],
#            [-0.4129,  0.0343,  0.1396,  ...,  1.6228, -1.6157,  1.1714],
#            [-0.3148, -0.0369,  0.1110,  ...,  1.3831, -1.3925,  0.9028]]]],
#
#
#
#         [[[[ 0.0552,  0.5317,  0.5295,  ..., -0.0731, -0.2252,  0.0196],
#            [-2.0945,  0.0116, -0.8654,  ..., -0.8724, -0.9924,  0.3873],
#            [-0.9469,  0.3648, -1.1638,  ..., -0.8540, -1.3454,  0.9339],
#            ...,
#            [-0.5100, -0.0535,  0.5398,  ..., -1.3263, -1.7471,  1.2681],
#            [-0.3163, -0.1455,  0.0764,  ..., -1.3727, -1.5449,  1.4536],
#            [-0.0789, -0.1795, -0.9387,  ..., -1.1192, -1.3972,  0.5120]],
#
#           [[-0.0601, -0.3936,  0.0745,  ...,  0.4253,  0.4963,  0.5316],
#            [-0.1687,  0.3556, -0.3881,  ..., -0.6594, -0.4454, -0.1677],
#            [ 0.5371,  0.7499, -0.6113,  ..., -0.8731, -1.1460, -0.6331],
#            ...,
#            [ 0.5081,  0.6828, -0.5418,  ..., -1.2132, -1.0416, -0.7410],
#            [ 1.1778,  0.4289, -0.2613,  ..., -0.8935, -0.3203, -0.6763],
#            [-0.0102,  0.0189, -0.2817,  ..., -0.8934, -0.4127, -0.1815]],
#
#           [[-0.0408,  0.3479,  0.5089,  ...,  1.2307,  0.8891,  0.2085],
#            [ 0.1789, -0.3935, -0.0379,  ...,  1.2651,  0.6142,  0.5932],
#            [ 0.1796, -0.4455, -0.0925,  ...,  1.0010,  0.5736,  0.5438],
#            ...,
#            [ 0.5472, -0.0060, -0.3963,  ...,  1.2555,  0.8617,  0.5400],
#            [ 0.0981,  0.1672, -0.1309,  ...,  1.1869,  0.6910,  0.7599],
#            [-0.0519,  0.3428,  0.1502,  ...,  1.4397,  0.7842,  0.7374]],
#
#           ...,
#
#           [[-0.7178,  0.0251,  0.0275,  ...,  0.8255, -0.1660, -0.1873],
#            [-0.5204, -0.2522, -0.0775,  ...,  0.1294, -0.1471,  0.1392],
#            [-0.1134, -0.1637, -0.0870,  ...,  0.0523, -0.1457,  0.1636],
#            ...,
#            [-0.1182, -0.0952,  0.0268,  ..., -0.1569, -0.0494, -0.0504],
#            [-0.7458, -0.4162,  0.0693,  ..., -0.4937,  0.1882, -0.2142],
#            [ 0.3449, -0.1817,  0.0792,  ..., -0.3385, -0.0572,  0.6418]],
#
#           [[ 0.2312,  0.2540, -0.0892,  ..., -0.3061,  0.4718,  0.3059],
#            [ 0.0311, -0.1132,  0.0414,  ..., -0.4607, -0.0194, -0.7185],
#            [-0.6061, -0.3382, -0.5118,  ...,  0.1854, -0.4115,  0.4283],
#            ...,
#            [ 0.2506,  0.2907,  0.4840,  ...,  0.1144, -0.6705,  0.4692],
#            [-0.5397,  0.4722, -0.6603,  ...,  0.5430, -0.9819,  0.1933],
#            [-0.2773,  0.0738,  0.0309,  ...,  0.1837, -0.3404, -0.7814]],
#
#           [[-0.0152, -0.0364,  0.0847,  ...,  0.4414, -0.4385,  0.2955],
#            [-0.1072, -0.0936,  0.2509,  ...,  1.0719, -1.1046,  0.7198],
#            [ 0.1070,  0.2247,  0.1788,  ...,  1.3554, -1.3737,  0.9566],
#            ...,
#            [-0.2957,  0.0975,  0.4114,  ...,  1.6285, -1.7045,  1.1580],
#            [-0.4402,  0.0335,  0.0903,  ...,  1.6294, -1.6230,  1.1780],
#            [-0.3136, -0.0339,  0.1173,  ...,  1.4051, -1.4131,  0.9186]]]],
#
#
#
#         [[[[ 0.0552,  0.5317,  0.5295,  ..., -0.0731, -0.2252,  0.0196],
#            [-2.0945,  0.0116, -0.8654,  ..., -0.8724, -0.9924,  0.3873],
#            [-0.9469,  0.3648, -1.1638,  ..., -0.8540, -1.3454,  0.9339],
#            ...,
#            [-0.3680, -0.0854,  0.5195,  ..., -1.2634, -1.6548,  1.1267],
#            [-0.0104, -0.3226,  0.0563,  ..., -1.3256, -1.4757,  1.3971],
#            [ 0.0590, -0.2907, -1.0634,  ..., -1.1000, -1.3612,  0.4673]],
#
#           [[-0.0601, -0.3936,  0.0745,  ...,  0.4253,  0.4963,  0.5316],
#            [-0.1687,  0.3556, -0.3881,  ..., -0.6594, -0.4454, -0.1677],
#            [ 0.5371,  0.7499, -0.6113,  ..., -0.8731, -1.1460, -0.6331],
#            ...,
#            [ 0.3907,  0.6708, -0.4214,  ..., -1.1239, -0.9813, -0.6820],
#            [ 1.1054,  0.3034, -0.2530,  ..., -0.8414, -0.3092, -0.6626],
#            [-0.0162, -0.0984, -0.3043,  ..., -0.8498, -0.4194, -0.1601]],
#
#           [[-0.0408,  0.3479,  0.5089,  ...,  1.2307,  0.8891,  0.2085],
#            [ 0.1789, -0.3935, -0.0379,  ...,  1.2651,  0.6142,  0.5932],
#            [ 0.1796, -0.4455, -0.0925,  ...,  1.0010,  0.5736,  0.5438],
#            ...,
#            [ 0.5620, -0.0663, -0.3758,  ...,  1.3043,  0.8559,  0.5013],
#            [ 0.1220,  0.0434, -0.1358,  ...,  1.2199,  0.6752,  0.7180],
#            [-0.0477,  0.3109,  0.1360,  ...,  1.4492,  0.7598,  0.7089]],
#
#           ...,
#
#           [[-0.7178,  0.0251,  0.0275,  ...,  0.8255, -0.1660, -0.1873],
#            [-0.5204, -0.2522, -0.0775,  ...,  0.1294, -0.1471,  0.1392],
#            [-0.1134, -0.1637, -0.0870,  ...,  0.0523, -0.1457,  0.1636],
#            ...,
#            [-0.1878, -0.0950,  0.0168,  ..., -0.0670, -0.0146, -0.0338],
#            [-0.6803, -0.4154,  0.0475,  ..., -0.4517,  0.2683, -0.2141],
#            [ 0.3103, -0.1397,  0.0636,  ..., -0.2677, -0.0155,  0.6383]],
#
# ...
#             -1.7096e-01, -2.0735e-01],
#            ...,
#            [ 4.6156e-01,  8.5942e-01,  4.1943e-01,  ..., -1.6609e-02,
#              2.0458e-01,  8.0890e-01],
#            [ 4.8180e-01,  2.9644e-01,  3.6255e-02,  ..., -1.6542e-01,
#             -2.3774e-01, -7.3622e-01],
#            [ 7.2057e-02, -5.9102e-01,  5.7880e-01,  ..., -2.7843e-01,
#             -7.7224e-01,  9.1252e-01]],
#
#           [[-4.1348e-03, -6.0709e-03,  4.4854e-04,  ..., -5.5454e-02,
#             -4.0896e-02, -1.1620e-02],
#            [ 9.7784e-02,  3.3791e-01,  2.2618e-01,  ...,  8.6790e-01,
#              1.1844e-01, -3.8076e-01],
#            [ 6.2451e-01,  1.1585e-01,  3.0405e-01,  ..., -8.0084e-01,
#             -1.9670e-01,  4.3243e-01],
#            ...,
#            [-5.1112e-01, -1.7190e-01, -1.0813e-01,  ..., -2.6270e-01,
#             -7.0755e-01,  2.5814e-01],
#            [-9.1958e-01,  6.0583e-02, -3.1995e-01,  ...,  1.3027e-01,
#              4.0875e-03,  8.7176e-01],
#            [-5.5894e-01,  3.5755e-02, -4.3475e-01,  ...,  2.8446e-01,
#             -1.6769e-01,  8.9982e-02]],
#
#           ...,
#
#           [[ 2.7821e-02, -3.8439e-02, -1.9837e-02,  ..., -9.1835e-03,
#              2.6278e-02, -3.9165e-02],
#            [ 1.0970e+00, -2.4939e-01,  9.5931e-01,  ..., -8.9036e-02,
#             -4.2690e-01,  2.0555e-01],
#            [-9.3777e-02, -8.1837e-02, -2.6073e-01,  ..., -3.9060e-01,
#              1.2071e-01, -1.0645e-01],
#            ...,
#            [ 2.1869e+00, -8.7471e-01, -1.1609e+00,  ...,  2.6794e-01,
#             -9.2778e-02, -9.2505e-01],
#            [-8.9288e-02, -1.9452e-01, -4.9842e-01,  ..., -8.5376e-01,
#              9.4729e-01, -6.9273e-01],
#            [-1.0577e-01,  2.2308e-01, -1.5239e-01,  ...,  2.3590e-01,
#              1.3657e-01, -1.4022e-01]],
#
#           [[-1.5109e-03, -3.7072e-02, -4.4938e-02,  ..., -3.5326e-02,
#             -1.1721e-02, -1.8468e-02],
#            [-4.8254e-01, -1.7153e-02, -4.1745e-01,  ...,  1.4997e-02,
]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 12
#       9 training = Llama_Leaner.Training(config, model, tokenizer)
#      10 solution = [tokenizer.encode("Numbers")[-1],tokenizer.encode("numbers")[-1]]
# ---> 12 trainings_logs = training.train(
#      13     dataset, specified_tokens=solution, n_top_tracked_tokens=10
#      14 )
#      15 trainings_logs.plot_losses(tokenizer)
#      16 trainings_logs.plot_top_tokens(tokenizer)
#
# File ~/ARENA-Hackathon/experiments/../lib/Llama_Leaner.py:427, in Training.train(self, dataset, specified_tokens, wandb_log, n_top_tracked_tokens)
#     423 for caches,tokens, target_tokens in dataloader:
#     425     magic_token_pos = tokens == self.magic_ids
# --> 427     losses = self.make_step(tokens, target_tokens, magic_token_pos, caches)
#     428     for key, value in losses.items():
#     429         self.loss_log[key].append(value)
#
# File ~/ARENA-Hackathon/experiments/../lib/Llama_Leaner.py:316, in Training.make_step(self, tokens, target_tokens, magic_token_pos, caches)
#     314 embeddings = self.create_modified_embeddings(tokens, magic_token_pos)
#     315 print(caches)
# --> 316 output_logits = self.model(inputs_embeds=embeddings, past_key_values = caches).logits
#     317 total_loss, label_loss, kl_loss, entropy_loss = self.calculate_losses(
#     318     output_logits, self.magic_token_vector, magic_token_pos, target_tokens
#     319 )
#     320 total_loss.backward()
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:1183, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1180 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1182 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1183 outputs = self.model(
#    1184     input_ids=input_ids,
#    1185     attention_mask=attention_mask,
#    1186     position_ids=position_ids,
#    1187     past_key_values=past_key_values,
#    1188     inputs_embeds=inputs_embeds,
#    1189     use_cache=use_cache,
#    1190     output_attentions=output_attentions,
#    1191     output_hidden_states=output_hidden_states,
#    1192     return_dict=return_dict,
#    1193 )
#    1195 hidden_states = outputs[0]
#    1196 if self.config.pretraining_tp > 1:
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:1070, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1060     layer_outputs = self._gradient_checkpointing_func(
#    1061         decoder_layer.__call__,
#    1062         hidden_states,
#    (...)
#    1067         use_cache,
#    1068     )
#    1069 else:
# -> 1070     layer_outputs = decoder_layer(
#    1071         hidden_states,
#    1072         attention_mask=attention_mask,
#    1073         position_ids=position_ids,
#    1074         past_key_value=past_key_values,
#    1075         output_attentions=output_attentions,
#    1076         use_cache=use_cache,
#    1077     )
#    1079 hidden_states = layer_outputs[0]
#    1081 if use_cache:
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:798, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     795 hidden_states = self.input_layernorm(hidden_states)
#     797 # Self Attention
# --> 798 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     799     hidden_states=hidden_states,
#     800     attention_mask=attention_mask,
#     801     position_ids=position_ids,
#     802     past_key_value=past_key_value,
#     803     output_attentions=output_attentions,
#     804     use_cache=use_cache,
#     805     **kwargs,
#     806 )
#     807 hidden_states = residual + hidden_states
#     809 # Fully Connected
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda/envs/my_env/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:691, in LlamaSdpaAttention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     678     logger.warning_once(
#     679         "LlamaModel is using LlamaSdpaAttention, but `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True`. Falling back to the manual attention implementation, "
#     680         'but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.'
#     681     )
#     682     return super().forward(
#     683         hidden_states=hidden_states,
#     684         attention_mask=attention_mask,
#    (...)
#     688         use_cache=use_cache,
#     689     )
# --> 691 bsz, q_len, _ = hidden_states.size()
#     693 query_states = self.q_proj(hidden_states)
#     694 key_states = self.k_proj(hidden_states)
#
# ValueError: too many values to unpack (expected 3)
